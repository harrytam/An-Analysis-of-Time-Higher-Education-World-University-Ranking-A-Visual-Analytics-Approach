# %% [markdown]
# # INM433 Visual Analytics Final assignment
# ## An Analysis of Time Higher Education World University Ranking: A Visual Analytics Approach
# ### Valli Ramaswamy, Ho Yin Tam

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
df_2011 = pd.read_csv('2011_rankings.csv')
df_2011.insert(0, 'Year', 2011)
df_2011
# Out:
#      Year  rank_order  rank                                         name  \
# 0    2011           1     1                           Harvard University
# 1    2011           2     2           California Institute of Technology
# 2    2011           3     3        Massachusetts Institute of Technology
# 3    2011           4     4                          Stanford University
# 4    2011           5     5                         Princeton University
# ..    ...         ...   ...                                          ...
# 195  2011         196   196                        Kent State University
# 196  2011         197   197               University of Illinois Chicago
# 197  2011         197   197                          Zhejiang University
# 198  2011         199   199                      Simon Fraser University
# 199  2011         199   199  Swedish University of Agricultural Sciences
#
#      scores_overall  scores_overall_rank  scores_teaching  \
# ...

# %%
df_2012 = pd.read_csv('2012_rankings.csv')
df_2012.insert(0, 'Year', 2012)
df_2012 = df_2012.head(200)
df_2012
# Out:
#      Year  rank_order rank                                name scores_overall  \
# 0    2012           1    1  California Institute of Technology           94.8
# 1    2012           2    2                  Harvard University           93.9
# 2    2012           2    2                 Stanford University           93.9
# 3    2012           4    4                University of Oxford           93.6
# 4    2012           5    5                Princeton University           92.9
# ..    ...         ...  ...                                 ...            ...
# 195  2012         196  196   Karlsruhe Institute of Technology           41.6
# 196  2012         197  197               Maastricht University           41.5
# 197  2012         197  197  Georgia Health Sciences University           41.5
# 198  2012         197  197             University of Leicester           41.5
# 199  2012         200  200                University of Twente           41.4
#
# ...

# %%
df_2013 = pd.read_csv('2013_rankings.csv')
df_2013.insert(0, 'Year', 2013)
df_2013 = df_2013.head(200)
df_2013
# Out:
#      Year  rank_order rank                                   name  \
# 0    2013           1    1     California Institute of Technology
# 1    2013           2    2                    Stanford University
# 2    2013           2    2                   University of Oxford
# 3    2013           4    4                     Harvard University
# 4    2013           5    5  Massachusetts Institute of Technology
# ..    ...         ...  ...                                    ...
# 195  2013         196  196                University of Leicester
# 196  2013         196  196                 University of Victoria
# 197  2013         198  198                  University at Buffalo
# 198  2013         199  199            Goethe University Frankfurt
# 199  2013         200  200         Birkbeck, University of London
#
#     scores_overall  scores_overall_rank  scores_teaching  \
# 0             95.5                    1             96.3
# ...

# %%
df_2014 = pd.read_csv('2014_rankings.csv')
df_2014.insert(0, 'Year', 2014)
df_2014 = df_2014.head(200)
df_2014
# Out:
#      Year  rank_order rank                                   name  \
# 0    2014           1    1     California Institute of Technology
# 1    2014           2    2                     Harvard University
# 2    2014           2    2                   University of Oxford
# 3    2014           4    4                    Stanford University
# 4    2014           5    5  Massachusetts Institute of Technology
# ..    ...         ...  ...                                    ...
# 195  2014         196  196                   University of Dundee
# 196  2014         197  197        Florida Institute of Technology
# 197  2014         198  198                   Newcastle University
# 198  2014         199  199                    Tel Aviv University
# 199  2014         199  199                    Boğaziçi University
#
#     scores_overall  scores_overall_rank  scores_teaching  \
# 0             94.9                    1             94.4
# ...

# %%
df_2015 = pd.read_csv('2015_rankings.csv')
df_2015.insert(0, 'Year', 2015)
df_2015 = df_2015.head(200)
df_2015
# Out:
#      Year  rank_order rank                                name scores_overall  \
# 0    2015           1    1  California Institute of Technology           94.3
# 1    2015           2    2                  Harvard University           93.3
# 2    2015           3    3                University of Oxford           93.2
# 3    2015           4    4                 Stanford University           92.9
# 4    2015           5    5             University of Cambridge           92.0
# ..    ...         ...  ...                                 ...            ...
# 195  2015         196  196   Lomonosov Moscow State University           46.0
# 196  2015         196  196   St George’s, University of London           46.0
# 197  2015         198  198           University of East Anglia           45.9
# 198  2015         199  199             University of Leicester           45.7
# 199  2015         200  200     Florida Institute of Technology           45.6
#
# ...

# %%
df_2016 = pd.read_csv('2016_rankings.csv')
df_2016 = df_2016.drop(columns = {'stats_number_students', 'stats_student_staff_ratio',
                                 'stats_pc_intl_students', 'stats_female_male_ratio'})
df_2016.insert(0, 'Year', 2016)
df_2016 = df_2016.head(200)
df_2016
# Out:
#      Year  rank_order   rank                                   name  \
# 0    2016           1      1     California Institute of Technology
# 1    2016           2      2                   University of Oxford
# 2    2016           3      3                    Stanford University
# 3    2016           4      4                University of Cambridge
# 4    2016           5      5  Massachusetts Institute of Technology
# ..    ...         ...    ...                                    ...
# 195  2016         196   =196                   Newcastle University
# 196  2016         197   =196      St George’s, University of London
# 197  2016         198    198                   University of Trento
# 198  2016         199    199     Paris Diderot University – Paris 7
# 199  2016         200    200             Queen’s University Belfast
#
#      scores_overall  scores_overall_rank  scores_citations  \
# 0              95.2                    1              99.8
# ...

# %%
df_2017 = pd.read_csv('2017_rankings.csv')
df_2017 = df_2017.drop(columns = {'stats_number_students', 'stats_student_staff_ratio',
                                 'stats_pc_intl_students', 'stats_female_male_ratio'})
df_2017.insert(0, 'Year', 2017)
df_2017 = df_2017.head(200)
df_2017
# Out:
#      Year  rank_order  rank                                   name  \
# 0    2017          10     1                   University of Oxford
# 1    2017          20     2     California Institute of Technology
# 2    2017          30     3                    Stanford University
# 3    2017          40     4                University of Cambridge
# 4    2017          50     5  Massachusetts Institute of Technology
# ..    ...         ...   ...                                    ...
# 195  2017        1960  =195                  University of Calgary
# 196  2017        1970  =195       National Taiwan University (NTU)
# 197  2017        1980   197           University of Duisburg-Essen
# 198  2017        1990  =198                    Brandeis University
# 199  2017        2000  =198                     Tilburg University
#
#     scores_overall  scores_overall_rank  scores_teaching  \
# 0             95.0                   10             89.6
# ...

# %%
df_2018 = pd.read_csv('2018_rankings.csv')
df_2018 = df_2018.drop(columns = ['stats_number_students', 'stats_student_staff_ratio',
                                 'stats_pc_intl_students', 'stats_female_male_ratio'])
df_2018.insert(0, 'Year', 2018)
df_2018 = df_2018.head(200)
df_2018
# Out:
#      Year  rank_order  rank                                   name  \
# 0    2018          10     1                   University of Oxford
# 1    2018          20     2                University of Cambridge
# 2    2018          30    =3     California Institute of Technology
# 3    2018          40    =3                    Stanford University
# 4    2018          50     5  Massachusetts Institute of Technology
# ..    ...         ...   ...                                    ...
# 195  2018        1960   196    Paris-Sorbonne University – Paris 4
# 196  2018        1970   197   Royal Holloway, University of London
# 197  2018        1980  =198    University of California, Riverside
# 198  2018        1990  =198               University of Gothenburg
# 199  2018        2000  =198       National Taiwan University (NTU)
#
#     scores_overall  scores_overall_rank  scores_teaching  \
# 0             94.3                   10             86.7
# ...

# %%
df_2019 = pd.read_csv('2019_rankings.csv')
df_2019 = df_2019.drop(columns = {'stats_number_students', 'stats_student_staff_ratio',
                                 'stats_pc_intl_students', 'stats_female_male_ratio'})
df_2019.insert(0, 'Year', 2019)
df_2019 = df_2019.head(200)
df_2019
# Out:
#      Year  rank_order  rank                                   name  \
# 0    2019          10     1                   University of Oxford
# 1    2019          20     2                University of Cambridge
# 2    2019          30     3                    Stanford University
# 3    2019          40     4  Massachusetts Institute of Technology
# 4    2019          50     5     California Institute of Technology
# ..    ...         ...   ...                                    ...
# 195  2019        1960   196        University of Technology Sydney
# 196  2019        1970   197                   University of Bergen
# 197  2019        1980   198                       Korea University
# 198  2019        1990  =199                  University of Calgary
# 199  2019        2000  =199      Lomonosov Moscow State University
#
#     scores_overall  scores_overall_rank  scores_teaching  \
# 0             96.0                   10             91.8
# ...

# %%
df_2020 = pd.read_csv('2020_rankings.csv')
df_2020 = df_2020.drop(columns = {'stats_number_students', 'stats_student_staff_ratio',
                                 'stats_pc_intl_students', 'stats_female_male_ratio'})
df_2020.insert(0, 'Year', 2020)
df_2020 = df_2020.head(200)
df_2020
# Out:
#      Year  rank_order  rank                                   name  \
# 0    2020          10     1                   University of Oxford
# 1    2020          20     2     California Institute of Technology
# 2    2020          30     3                University of Cambridge
# 3    2020          40     4                    Stanford University
# 4    2020          50     5  Massachusetts Institute of Technology
# ..    ...         ...   ...                                    ...
# 195  2020        1960  =194        University of the Witwatersrand
# 196  2020        1970   197       Yonsei University (Seoul campus)
# 197  2020        1980  =198                  University of Antwerp
# 198  2020        1990  =198                     Cardiff University
# 199  2020        2000  =198           George Washington University
#
#     scores_overall  scores_overall_rank  scores_teaching  \
# 0             95.4                   10             90.5
# ...

# %%
df_2021 = pd.read_csv('2021_rankings.csv')
df_2021 = df_2021.drop(columns = {'stats_number_students', 'stats_student_staff_ratio',
                                 'stats_pc_intl_students', 'stats_female_male_ratio'})
df_2021.insert(0, 'Year', 2021)
df_2021 = df_2021.head(200)
df_2021
# Out:
#      Year  rank_order  rank                                   name  \
# 0    2021          10     1                   University of Oxford
# 1    2021          20     2                    Stanford University
# 2    2021          30     3                     Harvard University
# 3    2021          40     4     California Institute of Technology
# 4    2021          50     5  Massachusetts Institute of Technology
# ..    ...         ...   ...                                    ...
# 195  2021        1960  =195                  University of Münster
# 196  2021        1970   197                   Texas A&M University
# 197  2021        1980  =198                University of Barcelona
# 198  2021        1990  =198       University of Erlangen-Nuremberg
# 199  2021        2000  =200                  University of Calgary
#
#     scores_overall  scores_overall_rank  scores_teaching  \
# 0             95.6                   10             91.3
# ...

# %%
df_2022 = pd.read_csv('2022_rankings.csv')
df_2022 = df_2022.drop(columns = {'stats_number_students', 'stats_student_staff_ratio',
                                 'stats_pc_intl_students', 'stats_female_male_ratio'})
df_2022.insert(0, 'Year', 2022)
df_2022 = df_2022.head(200)
df_2022
# Out:
#      Year  rank_order  rank                                name  \
# 0    2022          10     1                University of Oxford
# 1    2022          20    =2  California Institute of Technology
# 2    2022          30    =2                  Harvard University
# 3    2022          40     4                 Stanford University
# 4    2022          50    =5             University of Cambridge
# ..    ...         ...   ...                                 ...
# 195  2022        1960   196          Medical University of Graz
# 196  2022        1970  =197    University of Erlangen-Nuremberg
# 197  2022        1980  =197                University of Geneva
# 198  2022        1990  =197             University of Hohenheim
# 199  2022        2000  =197         Sapienza University of Rome
#
#     scores_overall  scores_overall_rank  scores_teaching  \
# 0             95.7                   10             91.0
# 1             95.0                   20             93.6
# ...

# %%
df_2023 = pd.read_csv('2023_rankings.csv')
df_2023 = df_2023.drop(columns = {'stats_number_students', 'stats_student_staff_ratio',
                                 'stats_pc_intl_students', 'stats_female_male_ratio'})
df_2023.insert(0, 'Year', 2023)
df_2023 = df_2023.head(200)
df_2023
# Out:
#      Year  rank_order  rank                                   name  \
# 0    2023          10     1                   University of Oxford
# 1    2023          20     2                     Harvard University
# 2    2023          30    =3                University of Cambridge
# 3    2023          40    =3                    Stanford University
# 4    2023          50     5  Massachusetts Institute of Technology
# ..    ...         ...   ...                                    ...
# 195  2023        1960  =196       University of Erlangen-Nuremberg
# 196  2023        1970  =196                     Sichuan University
# 197  2023        1980  =198                      Durham University
# 198  2023        1990  =198             Queen’s University Belfast
# 199  2023        2000  =198                  University of Reading
#
#     scores_overall  scores_overall_rank  scores_teaching  \
# 0             96.4                   10             92.3
# ...

# %%
rk = pd.concat([df_2011, df_2012, df_2013, df_2014, df_2015, 
               df_2016, df_2017, df_2018, df_2019, df_2020, 
               df_2021, df_2022, df_2023], axis=0, ignore_index=True)
rk
# Out:
#       Year  rank_order  rank                                   name  \
# 0     2011           1     1                     Harvard University
# 1     2011           2     2     California Institute of Technology
# 2     2011           3     3  Massachusetts Institute of Technology
# 3     2011           4     4                    Stanford University
# 4     2011           5     5                   Princeton University
# ...    ...         ...   ...                                    ...
# 2595  2023        1960  =196       University of Erlangen-Nuremberg
# 2596  2023        1970  =196                     Sichuan University
# 2597  2023        1980  =198                      Durham University
# 2598  2023        1990  =198             Queen’s University Belfast
# 2599  2023        2000  =198                  University of Reading
#
#      scores_overall  scores_overall_rank  scores_teaching  \
# 0              96.1                    1             99.7
# ...

# %%
rk.to_csv('rank_from2011to2023.csv', index=False)
